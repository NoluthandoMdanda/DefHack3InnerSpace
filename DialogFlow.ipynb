# %%
# !pip install --upgrade pip
# !yes | pip uninstall dialogflow
# !pip install dialogflow==0.3.0
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/27/79/8a850fe3496446ff0d584327ae44e7500daf6764ca1a382d2d02789accf7/pip-20.3.4-py2.py3-none-any.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 3.8MB/s ta 0:00:011
# Installing collected packages: pip
#   Found existing installation: pip 18.1
#     Uninstalling pip-18.1:
#       Successfully uninstalled pip-18.1
# Successfully installed pip-20.3.4
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# WARNING: Skipping dialogflow as it is not installed.
# yes: standard output: Broken pipe
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# Collecting dialogflow==0.3.0
#   Downloading dialogflow-0.3.0.tar.gz (170 kB)
#      |████████████████████████████████| 170 kB 5.5 MB/s eta 0:00:01
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=0.1.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from dialogflow==0.3.0) (1.22.2)
# Requirement already satisfied: googleapis-common-protos[grpc]<2.0dev,>=1.5.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from dialogflow==0.3.0) (1.6.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (1.32.0)
# Requirement already satisfied: futures>=3.2.0; python_version < "3.2" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (3.2.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (3.13.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (2.18.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (1.16.0)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (44.0.0.post20200106)
# Requirement already satisfied: pytz in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (2018.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0; extra == "grpc" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (1.31.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (3.1.1)
# Requirement already satisfied: rsa<4.6; python_version < "3.6" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (0.2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (2019.11.28)
# Requirement already satisfied: enum34>=1.0.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from grpcio<2.0dev,>=1.29.0; extra == "grpc"->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (1.1.6)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/envs/py2env/lib/python2.7/site-packages (from rsa<4.6; python_version < "3.6"->google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=0.1.4->dialogflow==0.3.0) (0.4.8)
# Building wheels for collected packages: dialogflow
#   Building wheel for dialogflow (setup.py) ... done
#   Created wheel for dialogflow: filename=dialogflow-0.3.0-py2.py3-none-any.whl size=220125 sha256=489aee576ea82b788e8ba4975d59cdcd9d83d4bea3c79915884b8ec16e8a62bb
#   Stored in directory: /content/.cache/pip/wheels/a6/e4/41/e70be94e2e0cdfffab860ac5332af06a56eb3224cba5e81258
# Successfully built dialogflow
# Installing collected packages: dialogflow
# Successfully installed dialogflow-0.3.0

# %%
from google.cloud import datastore

client = datastore.Client()
query = client.query(kind='Topic')
results = list(query.fetch())

# %%
import dialogflow

entity_types_client = dialogflow.EntityTypesClient()

project_id = !(gcloud config get-value project)

project_agent_path = entity_types_client.project_agent_path(
        project_id[0])

for element in entity_types_client.list_entity_types(project_agent_path):
  if (element.display_name == 'Topic'):
    entity_type_path = element.name

project_id = !(gcloud config get-value project)

entities = []

for result in results:
  
  entity = dialogflow.types.EntityType.Entity()
  entity.value = result.key.name
  entity.synonyms.append(result.key.name)

  entities.append(entity)

print entities

response = entity_types_client.batch_create_entities(
        entity_type_path, entities)

print('Entity created: {}'.format(response))
# Out:
# [value: "anxiety disorder"
# synonyms: "anxiety disorder"
# , value: "anxious"
# synonyms: "anxious"
# , value: "appetite loss"
# synonyms: "appetite loss"
# , value: "avoid stress"
# synonyms: "avoid stress"
# , value: "cognitive behavioural therapy"
# synonyms: "cognitive behavioural therapy"
# , value: "cold hands"
# synonyms: "cold hands"
# , value: "creative work"
# synonyms: "creative work"
# , value: "depression"
# synonyms: "depression"
# , value: "exercise"
# synonyms: "exercise"
# , value: "fear"
# synonyms: "fear"
# , value: "generalized anxiety disorder."
# synonyms: "generalized anxiety disorder."
# , value: "healthcare"
# synonyms: "healthcare"
# , value: "healthy diet"
# synonyms: "healthy diet"
# , value: "loss of intent"
# synonyms: "loss of intent"
# , value: "loss of pleasure"
# synonyms: "loss of pleasure"
# , value: "no concentration"
# synonyms: "no concentration"
# , value: "obsessive compulsive disorder"
# synonyms: "obsessive compulsive disorder"
# , value: "overeating"
# synonyms: "overeating"
# , value: "panic"
# synonyms: "panic"
# , value: "panic disorder"
# synonyms: "panic disorder"
# , value: "psychotherapy-talk therapy"
# synonyms: "psychotherapy-talk therapy"
# , value: "pyschological counselling"
# synonyms: "pyschological counselling"
# , value: "relaxation therapy"
# synonyms: "relaxation therapy"
# , value: "social anxiety disorder"
# synonyms: "social anxiety disorder"
# , value: "sport"
# synonyms: "sport"
# , value: "sweaty"
# synonyms: "sweaty"
# , value: "symptoms"
# synonyms: "symptoms"
# , value: "thoughts of death"
# synonyms: "thoughts of death"
# , value: "tiredness"
# synonyms: "tiredness"
# , value: "treatment"
# synonyms: "treatment"
# ]
# Entity created: <google.api_core.operation.Operation object at 0x7fc6281a6dd0>
